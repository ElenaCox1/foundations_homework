# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get('https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors')
doc = BeautifulSoup(response.text)

# %%
books = doc.find_all('tr')

len(books)
# Out:
# 100

# %%
rows = []

for book in books:
    row = {}
    row['Rank'] = book.find(class_="number").text
    row['Title'] = book.find(class_="bookTitle").text.strip()
    row['Author'] = book.find(class_="authorName").text.strip()
    row['Score'] = book.find(href="#").text.strip()
    row['Votes'] = book.find(href="#").find_next_sibling('a').text
    row['Rating'] = book.find(class_="minirating").text

    
    rows.append(row)

# %%
df = pd.DataFrame(rows)

df
# Out:
#                          Author Rank  \
# 0               Margaret Atwood    1
# 1               Suzanne Collins    2
# 2   Mary Wollstonecraft Shelley    3
# 3             Madeleine L'Engle    4
# 4             Ursula K. Le Guin    5
# 5                 Veronica Roth    6
# 6               Suzanne Collins    7
# 7                    Lois Lowry    8
# 8             Octavia E. Butler    9
# 9             Ursula K. Le Guin   10
# 10              Margaret Atwood   11
# 11              Suzanne Collins   12
# 12           Audrey Niffenegger   13
# 13                Connie Willis   14
# 14            Ursula K. Le Guin   15
# 15                   Ann Leckie   16
# 16         Lois McMaster Bujold   17
# 17                Connie Willis   18
# 18           Mary Doria Russell   19
# 19               Anne McCaffrey   20
# 20            Octavia E. Butler   21
# 21         Lois McMaster Bujold   22
# 22         Lois McMaster Bujold   23
# 23              Stephenie Meyer   24
# 24                Veronica Roth   25
# 25         Lois McMaster Bujold   26
# 26                   P.D. James   27
# 27                 G.S. Jennsen   28
# 28              Margaret Atwood   29
# 29               Anne McCaffrey   30
# ..                          ...  ...
# 70        Marion Zimmer Bradley   71
# 71                 Hayley Stone   72
# 72                 G.S. Jennsen   73
# 73         Lois McMaster Bujold   74
# 74            Octavia E. Butler   75
# 75            Ursula K. Le Guin   76
# 76               Elizabeth Moon   77
# 77            Ursula K. Le Guin   78
# 78                  Ann Aguirre   79
# 79              Nicola Griffith   80
# 80                   Beth Revis   81
# 81                 C.J. Cherryh   82
# 82                  Mya Robarts   83
# 83                Lauren Oliver   84
# 84            Vonda N. McIntyre   85
# 85               Pamela Sargent   86
# 86                 Martha Wells   87
# 87               Elizabeth Moon   88
# 88                 C.J. Cherryh   89
# 89                 Marge Piercy   89
# 90            Maureen F. McHugh   91
# 91                   S.L. Viehl   92
# 92              Margaret Atwood   93
# 93                   Tanya Huff   94
# 94                Connie Willis   95
# 95                C.S. Friedman   96
# 96              Catherine Asaro   97
# 97                Marissa Meyer   98
# 98                  Nancy Kress   99
# 99                 Nancy Farmer  100
#
#                                               Rating          Score  \
# 0                4.09 avg rating — 1,102,318 ratings  score: 30,733
# 1                4.33 avg rating — 5,742,147 ratings  score: 28,553
# 2                3.78 avg rating — 1,023,439 ratings  score: 21,909
# 3                  4.01 avg rating — 903,270 ratings  score: 18,720
# 4                   4.06 avg rating — 98,786 ratings  score: 17,920
# 5                4.21 avg rating — 2,602,763 ratings  score: 13,326
# 6                4.29 avg rating — 2,200,701 ratings  score: 12,749
# 7                4.12 avg rating — 1,535,105 ratings  score: 12,399
# 8                   4.23 avg rating — 72,335 ratings  score: 11,070
# 9                   4.21 avg rating — 71,641 ratings  score: 10,731
# 10                 4.01 avg rating — 197,786 ratings  score: 10,117
# 11               4.03 avg rating — 2,071,958 ratings   score: 9,807
# 12               3.96 avg rating — 1,446,731 ratings   score: 9,193
# 13                  4.03 avg rating — 43,252 ratings   score: 8,935
# 14                  4.11 avg rating — 43,989 ratings   score: 7,775
# 15                  3.98 avg rating — 66,205 ratings   score: 7,336
# 16                  4.11 avg rating — 25,879 ratings   score: 7,017
# 17                  4.13 avg rating — 29,641 ratings   score: 6,890
# 18                  4.17 avg rating — 52,739 ratings   score: 6,873
# 19                 4.10 avg rating — 116,157 ratings   score: 6,802
# 20                  4.16 avg rating — 42,233 ratings   score: 6,653
# 21                  4.29 avg rating — 20,957 ratings   score: 6,087
# 22                  4.31 avg rating — 22,111 ratings   score: 5,623
# 23                 3.84 avg rating — 828,981 ratings   score: 5,274
# 24               4.05 avg rating — 1,045,826 ratings   score: 4,899
# 25                  4.45 avg rating — 13,949 ratings   score: 4,682
# 26                  3.68 avg rating — 36,106 ratings   score: 4,484
# 27                   3.91 avg rating — 2,146 ratings   score: 4,394
# 28                  4.06 avg rating — 92,226 ratings   score: 4,343
# 29                  4.09 avg rating — 17,772 ratings   score: 4,235
# ..                                               ...            ...
# 70                   3.88 avg rating — 5,954 ratings   score: 1,748
# 71                     3.79 avg rating — 248 ratings   score: 1,698
# 72                   4.22 avg rating — 1,042 ratings   score: 1,684
# 73                  4.06 avg rating — 11,942 ratings   score: 1,683
# 74                   4.33 avg rating — 3,945 ratings   score: 1,659
# 75                   4.04 avg rating — 4,041 ratings   score: 1,572
# 76                   4.06 avg rating — 3,627 ratings   score: 1,547
# 77                  3.95 avg rating — 12,904 ratings   score: 1,510
# 78                  3.73 avg rating — 12,661 ratings   score: 1,497
# 79                   3.86 avg rating — 3,715 ratings   score: 1,477
# 80                 3.77 avg rating — 107,418 ratings   score: 1,435
# 81                   4.19 avg rating — 3,610 ratings   score: 1,392
# 82                   4.02 avg rating — 7,836 ratings   score: 1,380
# 83                 3.98 avg rating — 392,285 ratings   score: 1,366
# 84                   3.86 avg rating — 8,405 ratings   score: 1,324
# 85     really liked it 4.00 avg rating — 272 ratings   score: 1,297
# 86                  4.15 avg rating — 35,062 ratings   score: 1,296
# 87                  3.98 avg rating — 11,161 ratings   score: 1,286
# 88                   4.17 avg rating — 4,058 ratings   score: 1,276
# 89                  3.95 avg rating — 12,598 ratings   score: 1,276
# 90                   3.94 avg rating — 3,453 ratings   score: 1,253
# 91                   3.80 avg rating — 3,632 ratings   score: 1,230
# 92  really liked it 4.00 avg rating — 52,198 ratings   score: 1,212
# 93                   3.98 avg rating — 6,898 ratings   score: 1,165
# 94                  3.93 avg rating — 10,069 ratings   score: 1,142
# 95                   4.04 avg rating — 3,261 ratings   score: 1,130
# 96                   3.74 avg rating — 3,686 ratings   score: 1,119
# 97                 4.29 avg rating — 265,278 ratings   score: 1,115
# 98                   3.61 avg rating — 1,292 ratings   score: 1,107
# 99                  4.10 avg rating — 72,363 ratings   score: 1,083
#
#                                                 Title             Votes
# 0                                 The Handmaid's Tale  314 people voted
# 1             The Hunger Games (The Hunger Games, #1)  292 people voted
# 2                                        Frankenstein  224 people voted
# 3                A Wrinkle in Time (Time Quintet, #1)  196 people voted
# 4        The Left Hand of Darkness (Hainish Cycle #4)  184 people voted
# 5                           Divergent (Divergent, #1)  138 people voted
# 6                Catching Fire (The Hunger Games, #2)  133 people voted
# 7                           The Giver (The Giver, #1)  129 people voted
# 8                                             Kindred  116 people voted
# 9                 The Dispossessed (Hainish Cycle #6)  112 people voted
# 10                     Oryx and Crake (MaddAddam, #1)  107 people voted
# 11                  Mockingjay (The Hunger Games, #3)  104 people voted
# 12                           The Time Traveler's Wife   98 people voted
# 13             Doomsday Book (Oxford Time Travel, #1)   96 people voted
# 14                                The Lathe of Heaven   84 people voted
# 15              Ancillary Justice (Imperial Radch #1)   81 people voted
# 16            Shards of Honour  (Vorkosigan Saga, #1)   75 people voted
# 17  To Say Nothing of the Dog (Oxford Time Travel,...   74 people voted
# 18                      The Sparrow (The Sparrow, #1)   72 people voted
# 19            Dragonflight (Dragonriders of Pern, #1)   74 people voted
# 20               Parable of the Sower (Earthseed, #1)   71 people voted
# 21     The Warrior's Apprentice (Vorkosigan Saga, #2)   65 people voted
# 22                     Barrayar (Vorkosigan Saga, #7)   60 people voted
# 23                            The Host (The Host, #1)   56 people voted
# 24                          Insurgent (Divergent, #2)   54 people voted
# 25                      Memory (Vorkosigan Saga, #10)   51 people voted
# 26                                The Children of Men   49 people voted
# 27  Starshine: Aurora Rising Book One (Aurora Rhap...   45 people voted
# 28             The Year of the Flood  (MaddAddam, #2)   47 people voted
# 29                Crystal Singer (Crystal Singer, #1)   47 people voted
# ..                                                ...               ...
# 70                                  Darkover Landfall   21 people voted
# 71                    Machinations (Machinations, #1)   17 people voted
# 72                      Vertigo (Aurora Rhapsody, #2)   18 people voted
# 73                    CryoBurn (Vorkosigan Saga, #14)   24 people voted
# 74              Seed to Harvest (Patternmaster, #1-4)   20 people voted
# 75                         The Wind's Twelve Quarters   19 people voted
# 76                                 Remnant Population   20 people voted
# 77                       The Word for World is Forest   20 people voted
# 78                       Grimspace (Sirantha Jax, #1)   17 people voted
# 79                                           Ammonite   20 people voted
# 80      Across the Universe (Across the Universe, #1)   16 people voted
# 81                          Inheritor (Foreigner, #3)   18 people voted
# 82                                         The V Girl   15 people voted
# 83                            Delirium (Delirium, #1)   15 people voted
# 84                                         Dreamsnake   18 people voted
# 85  Women of Wonder: Science-Fiction Stories by Wo...   16 people voted
# 86        All Systems Red (The Murderbot Diaries, #1)   14 people voted
# 87                Trading in Danger (Vatta's War, #1)   16 people voted
# 88                            Invader (Foreigner, #2)   17 people voted
# 89                          Woman on the Edge of Time   15 people voted
# 90                               China Mountain Zhang   18 people voted
# 91                              Stardoc (Stardoc, #1)   16 people voted
# 92                          MaddAddam (MaddAddam, #3)   13 people voted
# 93                 Valor's Choice (Confederation, #1)   16 people voted
# 94                                         Bellwether   13 people voted
# 95                                   This Alien Shore   15 people voted
# 96  Primary Inversion (Saga of the Skolian Empire,...   15 people voted
# 97                 Scarlet (The Lunar Chronicles, #2)   12 people voted
# 98                 Probability Moon (Probability, #1)   15 people voted
# 99     The House of the Scorpion (Matteo Alacran, #1)   12 people voted
#
# [100 rows x 6 columns]

# %%
df.to_csv("Goodreads", index=False)

# %%
df = pd.read_csv("Goodreads", encoding='latin-1', na_values=[0, "UNKNOWN"])
df.head(2)
# Out:
#             Author  Rank                                  Rating  \
# 0  Margaret Atwood     1   4.09 avg rating â 1,102,318 ratings
# 1  Suzanne Collins     2   4.33 avg rating â 5,742,147 ratings
#
#            Score                                    Title             Votes
# 0  score: 30,733                      The Handmaid's Tale  314 people voted
# 1  score: 28,553  The Hunger Games (The Hunger Games, #1)  292 people voted

# %%
df.dtypes
# Out:
# Author    object
# Rank       int64
# Rating    object
# Score     object
# Title     object
# Votes     object
# dtype: object

# %%
import re

# %%
df['Score'] = df['Score'].str.extract(r'score:(.*)')

# %%
df.head()
# Out:
#                         Author  Rank                                  Rating  \
# 0              Margaret Atwood     1   4.09 avg rating â 1,102,318 ratings
# 1              Suzanne Collins     2   4.33 avg rating â 5,742,147 ratings
# 2  Mary Wollstonecraft Shelley     3   3.78 avg rating â 1,023,439 ratings
# 3            Madeleine L'Engle     4     4.01 avg rating â 903,270 ratings
# 4            Ursula K. Le Guin     5      4.06 avg rating â 98,786 ratings
#
#      Score                                         Title             Votes
# 0   30,733                           The Handmaid's Tale  314 people voted
# 1   28,553       The Hunger Games (The Hunger Games, #1)  292 people voted
# 2   21,909                                  Frankenstein  224 people voted
# 3   18,720          A Wrinkle in Time (Time Quintet, #1)  196 people voted
# 4   17,920  The Left Hand of Darkness (Hainish Cycle #4)  184 people voted

# %%
df[['Rating','Number of ratings']] = df.Rating.str.split("â", expand=True)

# %%
df.head()
# Out:
#                         Author  Rank             Rating    Score  \
# 0              Margaret Atwood     1   4.09 avg rating    30,733
# 1              Suzanne Collins     2   4.33 avg rating    28,553
# 2  Mary Wollstonecraft Shelley     3   3.78 avg rating    21,909
# 3            Madeleine L'Engle     4   4.01 avg rating    18,720
# 4            Ursula K. Le Guin     5   4.06 avg rating    17,920
#
#                                           Title             Votes  \
# 0                           The Handmaid's Tale  314 people voted
# 1       The Hunger Games (The Hunger Games, #1)  292 people voted
# 2                                  Frankenstein  224 people voted
# 3          A Wrinkle in Time (Time Quintet, #1)  196 people voted
# 4  The Left Hand of Darkness (Hainish Cycle #4)  184 people voted
#
#       Number of ratings
# 0   1,102,318 ratings
# 1   5,742,147 ratings
# 2   1,023,439 ratings
# 3     903,270 ratings
# 4      98,786 ratings

# %%
df[['Title','Series']] = df.Title.str.split("\(", expand=True)

# %%
df.head()
# Out:
#                         Author  Rank             Rating    Score  \
# 0              Margaret Atwood     1   4.09 avg rating    30,733
# 1              Suzanne Collins     2   4.33 avg rating    28,553
# 2  Mary Wollstonecraft Shelley     3   3.78 avg rating    21,909
# 3            Madeleine L'Engle     4   4.01 avg rating    18,720
# 4            Ursula K. Le Guin     5   4.06 avg rating    17,920
#
#                         Title             Votes     Number of ratings  \
# 0         The Handmaid's Tale  314 people voted   1,102,318 ratings
# 1           The Hunger Games   292 people voted   5,742,147 ratings
# 2                Frankenstein  224 people voted   1,023,439 ratings
# 3          A Wrinkle in Time   196 people voted     903,270 ratings
# 4  The Left Hand of Darkness   184 people voted      98,786 ratings
#
#                   Series
# 0                   None
# 1  The Hunger Games, #1)
# 2                   None
# 3      Time Quintet, #1)
# 4      Hainish Cycle #4)

# %%
df[['Series','Number in Series']] = df.Series.str.split("\#", expand=True)

# %%
df.head(2)
# Out:
#             Author  Rank             Rating    Score                Title  \
# 0  Margaret Atwood     1   4.09 avg rating    30,733  The Handmaid's Tale
# 1  Suzanne Collins     2   4.33 avg rating    28,553    The Hunger Games
#
#               Votes     Number of ratings              Series Number in Series
# 0  314 people voted   1,102,318 ratings                None             None
# 1  292 people voted   5,742,147 ratings  The Hunger Games,                1)
